# %% [markdown]
# # Load COCO Dataset from Roboflow
#
# Import the COCO object detection dataset from Roboflow Universe into Pixeltable tables.
#
# **What's in this recipe:**
# - Import 1% sample of COCO training set from Roboflow
# - Load images with object detection annotations
# - Work with bounding boxes and class labels
# - Access COCO dataset without manual downloads

# %% [markdown]
# ## Problem
#
# COCO (Common Objects in Context) is one of the most important datasets for object detection with 123,272 labeled training images. You need a representative sample in Pixeltable to work with object detection models without downloading the massive 25GB+ full dataset.

# %% [markdown]
# ## Solution
#
# **What's in this recipe:**
# - Load ~1,233 images (1% of 123,272 training set) from COCO via Roboflow
# - Access object detection annotations (bounding boxes, labels)
# - Use Roboflow's API for easy dataset access
# - Work with standard COCO format in Pixeltable
#
# Roboflow hosts the [COCO dataset](https://universe.roboflow.com/microsoft/coco) and provides an easy API to download subsets without needing to download the entire dataset.

# %% [markdown]
# ### Setup

# %%
# !uv add pixeltable roboflow
# Out:
# Resolved 268 packages in 808ms
# ⠙ Preparing packages... (0/8)                                                   ⠋ Preparing packages... (0/0)
# ⠙ Preparing packages... (0/8)--------------     0 B/19.50 KiB
# ⠙ Preparing packages... (0/8)--------------     0 B/19.50 KiB
# filetype             ------------------------------     0 B/19.50 KiB
# ⠙ Preparing packages... (0/8)--------------     0 B/53.20 KiB
# filetype             ------------------------------     0 B/19.50 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/53.20 KiB
# filetype             ------------------------------ 16.00 KiB/19.50 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/53.20 KiB
# filetype             ------------------------------ 19.50 KiB/19.50 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/53.20 KiB
# filetype             ------------------------------ 19.50 KiB/19.50 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/53.20 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/53.20 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/53.20 KiB
# python-dotenv        ------------------------------     0 B/20.73 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/53.20 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/53.20 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/53.20 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.91 KiB/53.20 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# requests-toolbelt    ------------------------------ 14.91 KiB/53.20 KiB
# ⠙ Preparing packages... (0/8)--------------     0 B/87.83 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# requests-toolbelt    ------------------------------ 14.91 KiB/53.20 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/87.83 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# requests-toolbelt    ------------------------------ 30.91 KiB/53.20 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/87.83 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# requests-toolbelt    ------------------------------ 46.91 KiB/53.20 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/87.83 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# requests-toolbelt    ------------------------------ 53.20 KiB/53.20 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/87.83 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# requests-toolbelt    ------------------------------ 53.20 KiB/53.20 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/87.83 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/87.83 KiB
# python-dotenv        ------------------------------ 14.88 KiB/20.73 KiB
# ⠙ Preparing packages... (0/8)-------------- 14.88 KiB/87.83 KiB
# idna                   ------------------------------     0 B/65.27 KiB
# roboflow               ------------------------------ 30.88 KiB/87.83 KiB
# pi-heif                ------------------------------     0 B/871.38 KiB
# pillow-avif-plugin     ------------------------------     0 B/2.68 MiB
# ⠙ Preparing packages... (0/8)----------------     0 B/52.30 MiB
# idna                   ------------------------------ 16.00 KiB/65.27 KiB
# roboflow               ------------------------------ 78.88 KiB/87.83 KiB
# pi-heif                ------------------------------ 16.00 KiB/871.38 KiB
# pillow-avif-plugin     ------------------------------     0 B/2.68 MiB
# ⠙ Preparing packages... (0/8)----------------     0 B/52.30 MiB
# idna                   ------------------------------ 16.00 KiB/65.27 KiB
# pi-heif                ------------------------------ 16.00 KiB/871.38 KiB
# pillow-avif-plugin     ------------------------------ 16.00 KiB/2.68 MiB
# ⠙ Preparing packages... (0/8)---------------- 16.00 KiB/52.30 MiB
# pi-heif                ------------------------------ 80.00 KiB/871.38 KiB
# pillow-avif-plugin     ------------------------------ 80.00 KiB/2.68 MiB
# ⠙ Preparing packages... (0/8)---------------- 96.00 KiB/52.30 MiB
# pi-heif                ------------------------------ 224.00 KiB/871.38 KiB
# pillow-avif-plugin     ------------------------------ 208.00 KiB/2.68 MiB
# ⠹ Preparing packages... (5/8)---------------- 224.00 KiB/52.30 MiB
# pi-heif                ------------------------------ 871.38 KiB/871.38 KiB
# pillow-avif-plugin     ------------------------------ 944.00 KiB/2.68 MiB
# ⠹ Preparing packages... (5/8)---------------- 960.00 KiB/52.30 MiB
# pillow-avif-plugin     ------------------------------ 944.00 KiB/2.68 MiB
# ⠹ Preparing packages... (5/8)---------------- 960.00 KiB/52.30 MiB
# pillow-avif-plugin     ------------------------------ 1.02 MiB/2.68 MiB
# ⠹ Preparing packages... (5/8)---------------- 4.03 MiB/52.30 MiB
# pillow-avif-plugin     ------------------------------ 2.02 MiB/2.68 MiB
# ⠹ Preparing packages... (5/8)---------------- 4.89 MiB/52.30 MiB
# ⠹ Preparing packages... (5/8)---------------- 4.89 MiB/52.30 MiB
# ⠸ Preparing packages... (7/8)---------------- 5.25 MiB/52.30 MiB
# ⠸ Preparing packages... (7/8)---------------- 7.02 MiB/52.30 MiB
# ⠸ Preparing packages... (7/8)---------------- 7.05 MiB/52.30 MiB
# ⠸ Preparing packages... (7/8)---------------- 7.97 MiB/52.30 MiB
# ⠼ Preparing packages... (7/8)---------------- 8.42 MiB/52.30 MiB
# ⠼ Preparing packages... (7/8)---------------- 9.39 MiB/52.30 MiB
# ⠼ Preparing packages... (7/8)---------------- 10.40 MiB/52.30 MiB
# ⠼ Preparing packages... (7/8)---------------- 11.47 MiB/52.30 MiB
# ⠴ Preparing packages... (7/8)---------------- 12.61 MiB/52.30 MiB
# ⠴ Preparing packages... (7/8)---------------- 13.59 MiB/52.30 MiB
# ⠴ Preparing packages... (7/8)---------------- 14.81 MiB/52.30 MiB
# ⠴ Preparing packages... (7/8)---------------- 16.11 MiB/52.30 MiB
# ⠦ Preparing packages... (7/8)---------------- 17.39 MiB/52.30 MiB
# ⠦ Preparing packages... (7/8)---------------- 18.72 MiB/52.30 MiB
# ⠦ Preparing packages... (7/8)---------------- 20.12 MiB/52.30 MiB
# ⠧ Preparing packages... (7/8)---------------- 21.56 MiB/52.30 MiB
# ⠧ Preparing packages... (7/8)---------------- 22.98 MiB/52.30 MiB
# ⠧ Preparing packages... (7/8)---------------- 23.39 MiB/52.30 MiB
# ⠧ Preparing packages... (7/8)---------------- 24.02 MiB/52.30 MiB
# ⠧ Preparing packages... (7/8)m--------------- 24.96 MiB/52.30 MiB
# ⠇ Preparing packages... (7/8)m--------------- 26.02 MiB/52.30 MiB
# ⠇ Preparing packages... (7/8)2m-------------- 26.83 MiB/52.30 MiB
# ⠇ Preparing packages... (7/8)2m-------------- 27.02 MiB/52.30 MiB
# ⠇ Preparing packages... (7/8)------------- 28.48 MiB/52.30 MiB
# ⠋ Preparing packages... (7/8)------------ 30.11 MiB/52.30 MiB
# ⠋ Preparing packages... (7/8)------------ 31.01 MiB/52.30 MiB
# ⠋ Preparing packages... (7/8)------------ 31.87 MiB/52.30 MiB
# ⠋ Preparing packages... (7/8)------------ 33.02 MiB/52.30 MiB
# ⠙ Preparing packages... (7/8)------------ 33.89 MiB/52.30 MiB
# ⠙ Preparing packages... (7/8)------------ 35.61 MiB/52.30 MiB
# ⠙ Preparing packages... (7/8)------------ 36.02 MiB/52.30 MiB
# ⠙ Preparing packages... (7/8)------------ 37.69 MiB/52.30 MiB
# ⠹ Preparing packages... (7/8)------------ 39.02 MiB/52.30 MiB
# ⠹ Preparing packages... (7/8)------------ 40.12 MiB/52.30 MiB
# ⠹ Preparing packages... (7/8)------------ 42.09 MiB/52.30 MiB
# ⠹ Preparing packages... (7/8)------------ 44.06 MiB/52.30 MiB
# ⠸ Preparing packages... (7/8)------------ 45.97 MiB/52.30 MiB
# ⠸ Preparing packages... (7/8)------------ 48.00 MiB/52.30 MiB
# ⠸ Preparing packages... (7/8)------------ 49.02 MiB/52.30 MiB
# ⠸ Preparing packages... (7/8)------------ 50.09 MiB/52.30 MiB
# Prepared 8 packages in 2.40s
# Uninstalled 2 packages in 20ms
# Installed 8 packages in 6ms
#  + filetype==1.2.0
#  - idna==3.11
#  + idna==3.7
#  - opencv-python-headless==4.11.0.86
#  + opencv-python-headless==4.10.0.84
#  + pi-heif==1.1.1
#  + pillow-avif-plugin==1.5.2
#  + python-dotenv==1.2.1
#  + requests-toolbelt==1.0.0
#  + roboflow==1.2.11

# %%
import pixeltable as pxt
from roboflow import Roboflow

# %% [markdown]
# ### Download COCO Sample from Roboflow
#
# Note: You'll need a Roboflow API key. Get one free at https://roboflow.com

# %%
# Initialize Roboflow with your API key
# Get your API key from https://app.roboflow.com/settings/api
rf = Roboflow(api_key="YOUR_API_KEY_HERE")

# Access the COCO dataset
project = rf.workspace("microsoft").project("coco")
dataset = project.version(1).download("coco")

# The dataset is downloaded to a local directory
print(f"Dataset downloaded to: {dataset.location}")

# %% [markdown]
#  Specifically, the labeled dataset for object detection stands at 123,272 images.

# %%
# Create directory for COCO data
pxt.drop_dir('coco_roboflow', force=True)
pxt.create_dir('coco_roboflow')

# Create table with schema for images
t = pxt.create_table(
    'coco_roboflow.samples',
    schema={
        'image': pxt.Image,
        'image_id': pxt.String
    },
    comment='COCO object detection dataset (1% sample) from Roboflow'
)

# %%
import os
import glob

# Get all images from the train directory (sampling 1%)
train_dir = os.path.join(dataset.location, 'train')
all_images = glob.glob(os.path.join(train_dir, '*.jpg'))

# Take 1% sample
sample_size = max(1, len(all_images) // 100)
sampled_images = all_images[:sample_size]

# Prepare rows for insertion
rows = []
for img_path in sampled_images:
    image_id = os.path.basename(img_path).replace('.jpg', '')
    rows.append({
        'image': img_path,
        'image_id': image_id
    })

t.insert(rows)
print(f"Inserted {len(rows)} images (1% of training set)")

# %%
# View sample data
t.select(t.image, t.image_id).head(10)

# %%
# Check total count
t.count()

# %% [markdown]
# ### Publish to Pixeltable Cloud

# %%
# Publish the table to Pixeltable Cloud
pxt.publish(
    'coco_roboflow.samples',
    'pxt://pixeltable:roboflow/coco_sample',
    access='public'
)

# %% [markdown]
# ## See also
#
# - [COCO on Roboflow Universe](https://universe.roboflow.com/microsoft/coco)
# - [Roboflow Documentation](https://docs.roboflow.com/)
# - [COCO Dataset Website](https://cocodataset.org/)
